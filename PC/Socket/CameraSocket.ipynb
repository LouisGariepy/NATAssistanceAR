# %% [markdown]
# -------------------------
# ### Author: Anthony Melin
# ### Date: 2019 August 14
# -------------------------

# %% [markdown]
# # Import

# %%
from CameraSocket import CameraSocket

import sys
import cv2

# %% [markdown]
# # Define host/port

# %%
import socket   
hostname = socket.gethostname()   
IPAddr = socket.gethostbyname(hostname)      
print("Your Computer IP Address is:" + IPAddr)
# Out:
# Your Computer IP Address is:169.254.123.230

# %%
_host = IPAddr
_port = 9999

# %% [markdown]
# # Define socket and await connection

# %%
cameraSocket = CameraSocket().Bind(_host, _port)
connected = cameraSocket.WaitConnection()

# %% [markdown]
# Exit if connection failed

# %%
if not connected:
    SystemExit(0)

print("Connected to {}".format(cameraSocket.client))
# Out:
# Connected to None

# %% [markdown]
# # Run

# %%
while True:

    frame = cameraSocket.getFrame()

    # display
    cv2.imshow("frame", frame)
    if cv2.waitKey(10) == ord('q'): break

cameraSocket.Exit()
cameraSocket.close()

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# d:\EFREI\M2\sherbrooke\Semestre 2\OOP\Project_Gitlab\NATAssistanceAR\PC\Socket\CameraSocket.py in GetFrame(self)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-kh7iq4w7\opencv\modules\imgcodecs\src\loadsave.cpp:768: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# d:\EFREI\M2\sherbrooke\Semestre 2\OOP\Project_Gitlab\NATAssistanceAR\PC\Socket\UdpConnection.py in ClearReception(self)
#      87             self.settimeout(0.01)
# ---> 88             self.recv(65000)
#      89
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-72f51044536c> in <module>
#       1 while True:
#       2
# ----> 3     frame = socket.GetFrame()
#       4
#       5     # display
#
# d:\EFREI\M2\sherbrooke\Semestre 2\OOP\Project_Gitlab\NATAssistanceAR\PC\Socket\CameraSocket.py in GetFrame(self)
#
# d:\EFREI\M2\sherbrooke\Semestre 2\OOP\Project_Gitlab\NATAssistanceAR\PC\Socket\UdpConnection.py in ClearReception(self)
#      86         try:
#      87             self.settimeout(0.01)
# ---> 88             self.recv(65000)
#      89
#      90         except socket.timeout:
#
# KeyboardInterrupt:

# %%
cameraSocket.Exit()
cameraSocket.close()
